# %%
# Dependencies and Setup
import pandas as pd
import config

from sqlalchemy import create_engine
from sqlalchemy import inspect
import numpy as np
import json
import requests

# %%
#Connecting to RDS database using config for all personal data

rds_connection_string = f'{config.connection_string}'
engine = create_engine(rds_connection_string)
insp = inspect(engine)

# %%
#Checking if Rental data has been loaded into the database
pd.read_sql_query('select * from rental_info where bathroom<=bhk+1', con=engine).head()
# Out:
#    id   posted_on  bhk   rent  size            floor    area_type  \
# 0   1  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1   2  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2   3  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3   4  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4   5  2022-05-09    2   7500   850       1 out of 2  Carpet Area
#
#               area_locality     city furnishing_status  tenant_preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    bathroom point_of_contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# 4         1    Contact Owner

# %%
#Checking if Rental data has been loaded into the database
df=pd.read_sql_query('select * from rental_info where bathroom<=bhk+1 ', con=engine)
df
# Out:
#         id   posted_on  bhk   rent  size            floor    area_type  \
# 0        1  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1        2  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2        3  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3        4  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4        5  2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...    ...         ...  ...    ...   ...              ...          ...
# 4719  4742  2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4720  4743  2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4721  4744  2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4722  4745  2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4723  4746  2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  area_locality       city furnishing_status  tenant_preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# 1     Phool Bagan, Kankurgachi    Kolkata    Semi-Furnished  Bachelors/Family
# 2      Salt Lake City Sector 2    Kolkata    Semi-Furnished  Bachelors/Family
# 3                  Dumdum Park    Kolkata       Unfurnished  Bachelors/Family
# 4                South Dum Dum    Kolkata       Unfurnished         Bachelors
# ...                        ...        ...               ...               ...
# 4719              Bandam Kommu  Hyderabad    Semi-Furnished  Bachelors/Family
# 4720      Manikonda, Hyderabad  Hyderabad    Semi-Furnished  Bachelors/Family
# 4721      Himayath Nagar, NH 7  Hyderabad    Semi-Furnished  Bachelors/Family
# 4722                Gachibowli  Hyderabad    Semi-Furnished            Family
# 4723           Suchitra Circle  Hyderabad       Unfurnished         Bachelors
#
#       bathroom point_of_contact
# 0            2    Contact Owner
# 1            1    Contact Owner
# 2            1    Contact Owner
# 3            1    Contact Owner
# 4            1    Contact Owner
# ...        ...              ...
# 4719         2    Contact Owner
# 4720         3    Contact Owner
# 4721         3    Contact Agent
# 4722         2    Contact Agent
# 4723         2    Contact Owner
#
# [4724 rows x 13 columns]

# %%
# Drop the label to create the X data
X = df.drop('rent', axis=1)
X
# Out:
#         id   posted_on  bhk  size            floor    area_type  \
# 0        1  2022-05-18    2  1100  Ground out of 2   Super Area
# 1        2  2022-05-13    2   800       1 out of 3   Super Area
# 2        3  2022-05-16    2  1000       1 out of 3   Super Area
# 3        4  2022-07-04    2   800       1 out of 2   Super Area
# 4        5  2022-05-09    2   850       1 out of 2  Carpet Area
# ...    ...         ...  ...   ...              ...          ...
# 4719  4742  2022-05-18    2  1000       3 out of 5  Carpet Area
# 4720  4743  2022-05-15    3  2000       1 out of 4   Super Area
# 4721  4744  2022-07-10    3  1750       3 out of 5  Carpet Area
# 4722  4745  2022-07-06    3  1500     23 out of 34  Carpet Area
# 4723  4746  2022-05-04    2  1000       4 out of 5  Carpet Area
#
#                  area_locality       city furnishing_status  tenant_preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# 1     Phool Bagan, Kankurgachi    Kolkata    Semi-Furnished  Bachelors/Family
# 2      Salt Lake City Sector 2    Kolkata    Semi-Furnished  Bachelors/Family
# 3                  Dumdum Park    Kolkata       Unfurnished  Bachelors/Family
# 4                South Dum Dum    Kolkata       Unfurnished         Bachelors
# ...                        ...        ...               ...               ...
# 4719              Bandam Kommu  Hyderabad    Semi-Furnished  Bachelors/Family
# 4720      Manikonda, Hyderabad  Hyderabad    Semi-Furnished  Bachelors/Family
# 4721      Himayath Nagar, NH 7  Hyderabad    Semi-Furnished  Bachelors/Family
# 4722                Gachibowli  Hyderabad    Semi-Furnished            Family
# 4723           Suchitra Circle  Hyderabad       Unfurnished         Bachelors
#
#       bathroom point_of_contact
# 0            2    Contact Owner
# 1            1    Contact Owner
# 2            1    Contact Owner
# 3            1    Contact Owner
# 4            1    Contact Owner
# ...        ...              ...
# 4719         2    Contact Owner
# 4720         3    Contact Owner
# 4721         3    Contact Agent
# 4722         2    Contact Agent
# 4723         2    Contact Owner
#
# [4724 rows x 12 columns]

# %%
# finding unique values 
X.nunique()
# Out:
# id                   4724
# posted_on              81
# bhk                     6
# size                  610
# floor                 475
# area_type               3
# area_locality        2223
# city                    6
# furnishing_status       3
# tenant_preferred        3
# bathroom                7
# point_of_contact        3
# dtype: int64

# %%
# create data frame for the months( will get 3 months) instead of dates(it will be 81)

# %%
# One-hot encoding on furnishing status, area type, city, tenants preferred and point of contact

# %%
# Converting output labels to 0 and 1
y_label = LabelEncoder().fit_transform(df['rent'])
y_label

# %%
X_train, X_test, y_train, y_test = train_test_split(X_dummies, y_label, random_state=1)

# %%
# Try using googel api and locate the area/locality and find the real location. Otherwise drop the data which cann't be located.

# %%
# floor - create a new column and pull data and use one hot encoding on it.

# %%
df11=pd.read_sql_query('select * from rental_info where bathroom<=bhk+1', con=engine)
df11
# Out:
#         id   posted_on  bhk   rent  size            floor    area_type  \
# 0        1  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1        2  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2        3  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3        4  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4        5  2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...    ...         ...  ...    ...   ...              ...          ...
# 4719  4742  2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4720  4743  2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4721  4744  2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4722  4745  2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4723  4746  2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  area_locality       city furnishing_status  tenant_preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# 1     Phool Bagan, Kankurgachi    Kolkata    Semi-Furnished  Bachelors/Family
# 2      Salt Lake City Sector 2    Kolkata    Semi-Furnished  Bachelors/Family
# 3                  Dumdum Park    Kolkata       Unfurnished  Bachelors/Family
# 4                South Dum Dum    Kolkata       Unfurnished         Bachelors
# ...                        ...        ...               ...               ...
# 4719              Bandam Kommu  Hyderabad    Semi-Furnished  Bachelors/Family
# 4720      Manikonda, Hyderabad  Hyderabad    Semi-Furnished  Bachelors/Family
# 4721      Himayath Nagar, NH 7  Hyderabad    Semi-Furnished  Bachelors/Family
# 4722                Gachibowli  Hyderabad    Semi-Furnished            Family
# 4723           Suchitra Circle  Hyderabad       Unfurnished         Bachelors
#
#       bathroom point_of_contact
# 0            2    Contact Owner
# 1            1    Contact Owner
# 2            1    Contact Owner
# 3            1    Contact Owner
# 4            1    Contact Owner
# ...        ...              ...
# 4719         2    Contact Owner
# 4720         3    Contact Owner
# 4721         3    Contact Agent
# 4722         2    Contact Agent
# 4723         2    Contact Owner
#
# [4724 rows x 13 columns]

# %%
# Scaling the X data by using StandardScaler()
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_train_scaled

# %%
# Alternatively, scaling the data by using MinMaxScaler()
scaler = MinMaxScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_train_scaled
# Out:
# LogisticRegression()

# %%
# Transforming the test dataset based on the fit from the training dataset
X_test_scaled = scaler.transform(X_test)
X_test_scaled
# Out:
# LogisticRegression()

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
